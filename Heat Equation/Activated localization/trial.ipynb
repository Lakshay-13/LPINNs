# %%
from heat_equation import *
# Out:
# C:\Users\laksh\anaconda3\envs\torch\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
input_neurons=[16,32]
lr = 1e-2
activation = nn.Tanh
mu = True
sigma = True
initial_sigma=0.1
localization=True

# %%
he = HE(input_neurons=input_neurons, lr = lr, activation = activation, mu = mu, sigma = sigma, initial_sigma=initial_sigma, localization=localization)
he.train(3000)
# Out:
# Training Progress:   0%|                                                                      | 0/3000 [00:00<…
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 2
#       1 he = HE(input_neurons=input_neurons, lr = lr, activation = activation, mu = mu, sigma = sigma, initial_sigma=initial_sigma, localization=localization)
# ----> 2 he.train(3000)
#
# File D:\CODES\Research\localization\Heat Equation\Activated localization\heat_equation.py:176, in HE.train(self, epochs, name)
#     175 def train(self, epochs=100, name=None):
# --> 176     self.solver.fit(max_epochs=epochs)
#     177     render(self.solver, name=name)
#
# File ~\anaconda3\envs\torch\Lib\site-packages\neurodiffeq\solvers.py:493, in BaseSolver.fit(self, max_epochs, callbacks, tqdm_file, **kwargs)
#     491 # register local epoch (starting from 1 instead of 0) so it can be accessed by callbacks
# ...
