# %%
import time
start = time.time()

# %%
from harmonic_oscillator import *
# Out:
# C:\Users\laksh\anaconda3\Lib\site-packages\torch\__init__.py:614: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\tensor\python_tensor.cpp:453.)
#   _C._set_default_tensor_type(t)

# %%
t_0=0.0
u_0=0.0
u_0_prime = 1.0
t_min=0.0
t_max=4*np.pi
train_batch_size=256
valid_batch_size=64
input_neurons=[128]
lr = 1e-2
activation = nn.SiLU

# %%
n_runs = 5

# %%
random_numbers = np.random.randint(10000000, 100000000, size=n_runs)

# %%
def bootstrap():
    for i in range(len(random_numbers)):
        torch.manual_seed(random_numbers[i])
        print(f'Run {i + 1}:')
        oscillator = HO(t_0=t_0, u_0=u_0, u_0_prime = u_0_prime, t_min=t_min, t_max=t_max, 
                    train_batch_size=train_batch_size, valid_batch_size=64, mu=mu, 
                    sigma=sigma, input_neurons=input_neurons, lr = lr, activation=activation,initial_sigma=initial_sigma, sigma_min=sigma_min, sigma_max=sigma_max)
        oscillator.train(100)
        oscillator.train(900)
        # oscillator.train(2000)
        oscillator.train(4000)
        # oscillator.train(5000)

# %%
initial_sigma = None
sigma_min = None
sigma_max = None

# %%
mu=False
sigma=False
bootstrap()
# Out:
# Run 1:
# Training Progress:   0%|                                                                       | 0/100 [00:00<…
# Training Progress:   0%|                                                                       | 0/900 [00:00<…
# Training Progress:   0%|                                                                      | 0/4000 [00:00<…
# Run 2:
# Training Progress:   0%|                                                                       | 0/100 [00:00<…
# Training Progress:   0%|                                                                       | 0/900 [00:00<…
# Training Progress:   0%|                                                                      | 0/4000 [00:00<…
# Run 3:
# Training Progress:   0%|                                                                       | 0/100 [00:00<…
# Training Progress:   0%|                                                                       | 0/900 [00:00<…
# ...

# %%
mu=False
sigma=True
bootstrap()
# Out:
# Run 1:
# Training Progress:   0%|                                                                       | 0/100 [00:00<…
# Training Progress:   0%|                                                                       | 0/900 [00:00<…
# Training Progress:   0%|                                                                      | 0/4000 [00:00<…
# Run 2:
# Training Progress:   0%|                                                                       | 0/100 [00:00<…
# Training Progress:   0%|                                                                       | 0/900 [00:00<…
# Training Progress:   0%|                                                                      | 0/4000 [00:00<…
# Run 3:
# Training Progress:   0%|                                                                       | 0/100 [00:00<…
# Training Progress:   0%|                                                                       | 0/900 [00:00<…
# ...

# %%
mu=True
sigma=True
bootstrap()
# Out:
# Run 1:
# Training Progress:   0%|                                                                       | 0/100 [00:00<…
# Training Progress:   0%|                                                                       | 0/900 [00:00<…
# Training Progress:   0%|                                                                      | 0/4000 [00:00<…
# Run 2:
# Training Progress:   0%|                                                                       | 0/100 [00:00<…
# Training Progress:   0%|                                                                       | 0/900 [00:00<…
# Training Progress:   0%|                                                                      | 0/4000 [00:00<…
# Run 3:
# Training Progress:   0%|                                                                       | 0/100 [00:00<…
# Training Progress:   0%|                                                                       | 0/900 [00:00<…
# ...

# %%
# mu=False
# sigma=False
# oscillator = HO(t_0=t_0, u_0=u_0, u_0_prime = u_0_prime, t_min=t_min, t_max=t_max, 
#                     train_batch_size=train_batch_size, valid_batch_size=64, mu=mu, 
#                     sigma=sigma, input_neurons=input_neurons, lr = lr, activation=activation, initial_sigma=12/128)# sigma_min=sigma_min, sigma_max=sigma_max)
# oscillator.solver.fit(1000)
# solver = oscillator.solver
# t_vals = torch.linspace(solver.t_min, solver.t_max, 256, requires_grad = True)
# residuals = solver.get_residuals(t_vals)
# derivatives = []
# for res in residuals:
#     derivatives.append(diff(res, solver.best_nets[0].layers[0].weight,shape_check=False))
# derivatives = torch.stack(derivatives).cpu().detach().numpy()
# heatmap = np.zeros((256, 256))
# for i in range(derivatives.shape[1]):
#     heatmap += np.abs(derivatives[:,i,0].reshape(-1,1)*derivatives[:,i,0].reshape(1,-1))

# %%
# for i in range(128):
#     heatmap = np.abs(derivatives[:,i,0].reshape(-1,1)*derivatives[:,i,0].reshape(1,-1))
#     sns.heatmap(heatmap, xticklabels=False, yticklabels=False)
#     plt.show()

# %%
# count = 0
# for i in range(128):
#     plt.plot(derivatives[:,i,:])
#     count += 1
#     if count ==1:
#         break

# %%
print(f'Total time taken : {round((time.time()-start)/60, 2)} min.')
# Out:
# Total time taken : 14.72 min.
