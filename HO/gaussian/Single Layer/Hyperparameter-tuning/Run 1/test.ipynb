# %%
from harmonic_oscillator import *
# Out:
# C:\Users\laksh\anaconda3\Lib\site-packages\torch\__init__.py:614: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\tensor\python_tensor.cpp:453.)
#   _C._set_default_tensor_type(t)

# %%
t_0=0.0
u_0=0.0
u_0_prime = 1.0
t_min=0.0
t_max=4*np.pi
train_batch_size=256
valid_batch_size=64
lr = 1e-2
activation = nn.SiLU

# %%
input_neurons=[32, 32, 32]
initial_sigma, sigma_min, sigma_max = [None, 0.3, 0.7]
mu=True
sigma=True

# %%
oscillator = HO(t_0=t_0, u_0=u_0, u_0_prime = u_0_prime, t_min=t_min, t_max=t_max, 
                    train_batch_size=train_batch_size, valid_batch_size=64, mu=mu, 
                    sigma=sigma, input_neurons=input_neurons, lr = lr, activation=activation,initial_sigma=initial_sigma, 
                    sigma_min=sigma_min, sigma_max=sigma_max)

# %%
oscillator.train(1000)
# Out:
# Training Progress:   0%|                                                                      | 0/1000 [00:00<…
