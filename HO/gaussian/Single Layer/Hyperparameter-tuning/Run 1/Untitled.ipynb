# %%
from harmonic_oscillator import *

# %%
class SineActivation(nn.Module):
    def forward(self, input):
        return torch.sin(input)

# %%
t_0=0.0
u_0=0.0
u_0_prime = 1.0
t_min=0.0
t_max=4*np.pi
train_batch_size=256
valid_batch_size=64
lr = 1e-2

# %%
n_runs = 5

# %%
random_numbers = np.random.randint(1, 100000000, size=n_runs)

# %%
def bootstrap(count):
    for i in range(len(random_numbers)):
        torch.manual_seed(random_numbers[i])
        print(f'Run {i + 1}:')
        oscillator = HO(t_0=t_0, u_0=u_0, u_0_prime = u_0_prime, t_min=t_min, t_max=t_max, 
                    train_batch_size=train_batch_size, valid_batch_size=64, mu=mu, 
                    sigma=sigma, input_neurons=input_neurons, lr = lr, activation=activation,initial_sigma=initial_sigma, sigma_min=sigma_min, sigma_max=sigma_max)
        oscillator.train(100, name=str(count)+ '-' + str(i+1) + '-1.png')
        oscillator.train(900, name=str(count)+ '-' + str(i+1) + '-2.png')
        oscillator.train(4000, name=str(count)+ '-' + str(i+1) + '-3.png')
        oscillator.train(5000, name=str(count)+ '-' + str(i+1) + '-4.png')

# %%
activations = [SineActivation]
params_networks = [[1024], [2048]]
params_locals = [[None, 1.5, 2.5]]

# %%
count = 1
for k in activations:
    activation = k
    for j in params_networks:
        input_neurons=j
        for i in params_locals:
            initial_sigma, sigma_min, sigma_max = i
            print(f'Sigmas trainable; Activation: {k}; Network: {j}; Initial Sigma: {i[0]}, Sigma Range: {i[1]} - {i[2]}.')
            mu=False
            sigma=True
            try:
                bootstrap(count)
                count=count+1
            except Exception as e:
                print(e)
            print(f'Mus and Sigmas trainable; Network: {j}; Initial Sigma: {i[0]}, Sigma Range: {i[1]} - {i[2]}.')
            mu=True
            sigma=True
            try:
                bootstrap(count)
                count=count+1
            except Exception as e:
                print(e)

# %%
activations = [SineActivation]
params_networks = [[1024, 32]]
params_locals = [[None, 1.5, 2.5]]
for k in activations:
    activation = k
    for j in params_networks:
        input_neurons=j
        for i in params_locals:
            initial_sigma, sigma_min, sigma_max = i
            print(f'Sigmas trainable; Activation: {k}; Network: {j}; Initial Sigma: {i[0]}, Sigma Range: {i[1]} - {i[2]}.')
            mu=False
            sigma=True
            try:
                bootstrap(count)
                count=count+1
            except Exception as e:
                print(e)
            print(f'Mus and Sigmas trainable; Network: {j}; Initial Sigma: {i[0]}, Sigma Range: {i[1]} - {i[2]}.')
            mu=True
            sigma=True
            try:
                bootstrap(count)
                count=count+1
            except Exception as e:
                print(e)

# %%
activations = [nn.Tanh, nn.SiLU]
params_networks = [[1024], [2048], [1024, 32]]
params_locals = [[None, 1.5, 2.5]]
for k in activations:
    activation = k
    for j in params_networks:
        input_neurons=j
        for i in params_locals:
            initial_sigma, sigma_min, sigma_max = i
            print(f'Sigmas trainable; Activation: {k}; Network: {j}; Initial Sigma: {i[0]}, Sigma Range: {i[1]} - {i[2]}.')
            mu=False
            sigma=True
            try:
                bootstrap(count)
                count=count+1
            except Exception as e:
                print(e)
            print(f'Mus and Sigmas trainable; Network: {j}; Initial Sigma: {i[0]}, Sigma Range: {i[1]} - {i[2]}.')
            mu=True
            sigma=True
            try:
                bootstrap(count)
                count=count+1
            except Exception as e:
                print(e)
